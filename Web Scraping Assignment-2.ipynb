# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException
from selenium.webdriver.common.by import By
import time

import warnings
warnings.filterwarnings('ignore')

# %%
#let's first connect webdriver
driver = webdriver.Chrome(r"chromedriver.exe")

# %%
driver.maximize_window()

# %% [markdown]
# ## Q1

# %%
# opening webpage 'https://www.naukri.com/'

driver.get('https://www.naukri.com/')

# %%
#enter Job role 'Data Analyst' in input box

jobsearch = driver.find_element(By.CLASS_NAME,"suggestor-input ")
jobsearch.send_keys('Data Analyst')

# %%
#enter Location 'Bangalore' in location input box

location = driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys('Bangalore')

# %%
enter = driver.find_element(By.CLASS_NAME,'qsbSubmit')
enter.click()

# %%
job_title = []
job_location = []
company_name = []
experience_required = []

# %%
# scraping job title 
title_tag = driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')

for i in title_tag[0:10]:
    title = i.text
    job_title.append(title)
    
#scraping Location
location_tag = driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')

for i in location_tag[:10]:
    locat = i.text
    job_location.append(locat)
    
# Scraping campany Name
comName_tag = driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')

for i in comName_tag[:10]:
    name = i.text
    company_name.append(name)
    
# Scraping Experience
exp_tag = driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')

for i in exp_tag[:10]:
    experience = i.text
    experience_required.append(experience)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
df = pd.DataFrame({'Title':job_title,'Location':job_location,'Company Name':company_name,'Experience Required':experience_required})

# %%
df
# Out:
#                                                Title  \
# 0                           Senior Data Analyst - DC
# 1                                    Sr Data Analyst
# 2  Job Opportunity with Leading MNC - Senior Data...
# 3              Manager/Senior Manager - Data Analyst
# 4                                Junior Data Analyst
# 5               Data Analysts with Business Analysis
# 6                                    HR Data Analyst
# 7                                       Data Analyst
# 8          Immediate Hiring For MIS and Data Analyst
# 9                             Manager - Data Analyst
#
#                                             Location  \
# 0                                Bangalore/Bengaluru
# 1                       Hybrid - Bangalore/Bengaluru
# 2                                Bangalore/Bengaluru
# 3  Bangalore/Bengaluru, Mumbai, Hyderabad/Secunde...
# 4                                Bangalore/Bengaluru
# 5                                Bangalore/Bengaluru
# ...

# %% [markdown]
# ## Q2

# %%
# opening webPage 'https://www.naukri.com/'
driver.get('https://www.naukri.com/')

# %%
# enter job title 'Data Scientist' in input box
jobSearch = driver.find_element(By.CLASS_NAME,'suggestor-input ')
jobSearch.send_keys('Data Scientist')

# %%
# Enter Location 'Bangalore' in input box

location_ds = driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input')
location_ds.send_keys('Bangalore')

# %%
# Click Search Button
searchButton = driver.find_element(By.CLASS_NAME,'qsbSubmit')
searchButton.click()

# %%
job_title_ds = []
job_location_ds = []
company_name_ds= []

# %%
# Scraping Job Titles
jobTitle = driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')

for i in jobTitle[:10]:
    jobtitle = i.text
    job_title_ds.append(jobtitle)
    
# scraping Location
jobLoction = driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')

for i in jobLoction[:10]:
    loc = i.text
    job_location_ds.append(loc)
    
# Scraping Company Name
com_name = driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')

for i in com_name[:10]:
    company = i.text
    company_name_ds.append(company)

# %%
# creating DataFrame
df_ds = pd.DataFrame({'Title':job_title_ds,'Location':job_location_ds,'Company Name':company_name_ds})
df_ds
# Out:
#                                                Title  \
# 0                                     Data Scientist
# 1                            Data Science Specialist
# 2                   Analystics & Modeling Specialist
# 3                                Lead Data Scientist
# 4                                     Data Scientist
# 5                     Data Scientist Knowledge graph
# 6                                     Data Scientist
# 7                                  SOFTWARE ENGINEER
# 8                             Analytic Delivery Lead
# 9  Opportunity For Data Scientist/Sr. Data Scient...
#
#                                             Location        Company Name
# 0  Temp. WFH - Bangalore/Bengaluru, Hyderabad/Sec...       Tech Mahindra
# 1  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...           Accenture
# 2  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...           Accenture
# 3  Bangalore/Bengaluru, Noida, Hyderabad/Secunder...           Birlasoft
# ...

# %% [markdown]
# ## Q3

# %%
# opening webpage using URL 'https://www.naukri.com/'

driver.get('https://www.naukri.com/')

# %%
# enter Job Title 'Data Scientist' in input field

jobT = driver.find_element(By.CLASS_NAME,'suggestor-input ')
jobT.send_keys('Data Scientist')

# %%
# Clicking search button
clickSearch = driver.find_element(By.CLASS_NAME,'qsbSubmit')
clickSearch.click()

# %%
# filter Location 'Delhi/NCR'

loc_filter = driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[5]/div[2]/div[2]/label/i')
loc_filter.click()

# %%
# filter salary '3-6 lakhs'

salary_filter = driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[6]/div[2]/div[2]/label/i')
salary_filter.click()

# %%
# craeting empty list of requred data
job_title_fl = []
job_location_fl = []
companyName = []
experienceRequired = []

# %%
# scraping 10 Job Titles
jobTitle_fl = driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')

for i in jobTitle_fl[:10]:
    title = i.text
    job_title_fl.append(title)
    
# Scraping 10 Location respective job titles
location_fl = driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')

for i in location_fl[:10]:
    loc_fl = i.text
    job_location_fl.append(loc_fl)
    
# Scraping 10 Company name respective jo titles
company_fl = driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')

for i in company_fl[:10]:
    company = i.text
    companyName.append(company)
    
# scraping 10 experience required data respective job title

exp_fl = driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')

for i in exp_fl[:10]:
    exper = i.text
    experienceRequired.append(exper)

# %%
# Creating Data Frame
df_filter = pd.DataFrame({'Title':job_title_fl,'Location':job_location_fl,'Company Name':companyName,'Experience Required':experienceRequired})
df_filter
# Out:
#                                         Title  \
# 0                        Analyst-Data Science
# 1                              Data Scientist
# 2  AWS Data Warehouse Developer - IT Industry
# 3                              Data Scientist
# 4                       SE/SSE-Data Scientist
# 5               Occupancy Surveyor - Gurugram
# 6                              Data Scientist
# 7                       Junior Data Scientist
# 8                                     Modeler
# 9                    Associate Data Scientist
#
#                                             Location  \
# 0                                   Gurgaon/Gurugram
# 1  Delhi / NCR, Noida(Sector-136 Noida), Ghaziaba...
# 2      Delhi / NCR, Bangalore/Bengaluru, Maharashtra
# 3                                              Noida
# 4                                        Delhi / NCR
# 5                                   Gurgaon/Gurugram
# 6  Dehradun, Hyderabad/Secunderabad, Gurgaon/Guru...
# ...

# %% [markdown]
# ## Q4

# %%
# Open webpage by url 'https://www.flipkart.com/'

driver.get('https://www.flipkart.com/')

# %%
# Closing OTP dialog box

closeDialog = driver.find_element(By.XPATH,'//button[@class="_2KpZ6l _2doB4z"]')
closeDialog.click()

# %%
# enter our search product 'sunglasses'

enterPro = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')
enterPro.send_keys('sunglasses')

# %%
# click search icon
clicksearchicon = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button')
clicksearchicon.click()

# %%
# create empty list of required data
brand = []
productDecrip = []
price = []

# %%
# Scraping 100 sunglasses brand name, product description,and price

for page in range(0,3):
    brandName = driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]') # extract brand Name
    for i in brandName:
        brand.append(i.text)
    pro_des = driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]') # extract Product description
    for i in pro_des:
        productDecrip.append(i.text)
    pri = driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]') # extract price
    for i in pri:
        price.append(i.text)
    next_button = driver.find_element(By.XPATH,'//a[@class="ge-49M"]') #click next page
    next_button.click()
    time.sleep(3)

# %%
# creating Data Frame
GlassesData = pd.DataFrame({'Brand Name':brand[:100],'Product Description':productDecrip[:100],'Price':price[:100]})
GlassesData
# Out:
#         Brand Name                                Product Description Price
# 0    VINCENT CHASE  by Lenskart Polarized, UV Protection Round Sun...  ₹949
# 1    VINCENT CHASE  by Lenskart Polarized, UV Protection Cat-eye S...  ₹899
# 2        Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...  ₹149
# 3         Fastrack      UV Protection Wayfarer Sunglasses (Free Size)  ₹599
# 4         Fastrack   UV Protection Rectangular Sunglasses (Free Size)  ₹499
# ..             ...                                                ...   ...
# 95  ROZZETTA CRAFT  Gradient, Toughened Glass Lens, UV Protection ...  ₹399
# 96        Fastrack  Riding Glasses, Night Vision Spectacle Sunglas...  ₹579
# 97        Fastrack  Polarized, Riding Glasses Sports, Wrap-around ...  ₹519
# 98       Elligator  Gradient, UV Protection Wayfarer Sunglasses (F...  ₹149
# 99    Singco India              UV Protection Aviator Sunglasses (55)  ₹664
#
# [100 rows x 3 columns]

# %% [markdown]
# ## Q5

# %%
# open webpage with URL 'https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&marketplace=FLIPKART'

driver.get('https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&marketplace=FLIPKART')

# %%
# creating empty list of required data
ratings = []
review_summary = []
full_reviews = []

# %%
# scraping reviews, review summary, and full reviews

for page in range(1,11):
    Rate = driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
    for i in Rate:
        ratings.append(i.text)
    rev_sum = driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
    for i in rev_sum:
        review_summary.append(i.text)
    full_re = driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
    for i in full_re:
        full_reviews.append(i.text)

# %%
df_Iphone11_reviews = pd.DataFrame({'Ratings':ratings[:100],'Review Summary':review_summary[:100],'Full Review':full_reviews[:100]})
df_Iphone11_reviews
# Out:
#    Ratings       Review Summary  \
# 0        5       Simply awesome
# 1        5     Perfect product!
# 2        5  Best in the market!
# 3        4      Value-for-money
# 4        5   Highly recommended
# ..     ...                  ...
# 95       5    Worth every penny
# 96       5     Perfect product!
# 97       5   Highly recommended
# 98       5        Great product
# 99       5            Fabulous!
#
#                                           Full Review
# 0   Really satisfied with the Product I received.....
# 1   Amazing phone with great cameras and better ba...
# 2   Great iPhone very snappy experience as apple k...
# 3   I'm Really happy with the product\nDelivery wa...
# 4   It's my first time to use iOS phone and I am l...
# ..                                                ...
# 95  Previously I was using one plus 3t it was a gr...
# 96  Value for money\n5 star rating\nExcellent came...
# 97  What a camera .....just awesome ..you can feel...
# ...

# %% [markdown]
# ## Q6

# %%
# Open webpage with URL 'https://www.flipkart.com/'

driver.get('https://www.flipkart.com/')

# %%
# enter 'sneakers' in search box

sne_search = driver.find_element(By.XPATH,'/html/body/div/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')
sne_search.send_keys('sneakers')

# %%
# click search icon
click_search_icon = driver.find_element(By.XPATH,'/html/body/div/div/div[1]/div[1]/div[2]/div[2]/form/div/button')
click_search_icon.click()

# %%
# creating empty list of required data information
BrandName = []
ProductDescription = []
Price_seakers = []

# %%
# Scraping sneakers 'Brand', 'Product Description', and 'price'

for page in range(1,4):
    brand_name = driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]') # Sraping Brand Name
    for i in brand_name:
        BrandName.append(i.text)
        
    productdecrip = driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]') # Scraping Product Descriptions
    for i in productdecrip:
        ProductDescription.append(i.text)
        
    priceSeakers = driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]') # Scraping Price
    for i in priceSeakers:
        Price_seakers.append(i.text)

# %%
Sneakers_data =pd.DataFrame({'Brand Name':BrandName[:100],'Product Description':ProductDescription[:100],'Price of Sneakers':Price_seakers[:100]})
Sneakers_data
# Out:
#              Brand Name                                Product Description  \
# 0   World Wear Footwear  5011-Latest Collection Stylish & Trendy Casual...
# 1                  aadi  Mesh |Lightweight|Comfort|Summer|Trendy|Walkin...
# 2              RED TAPE                                   Sneakers For Men
# 3                Kzaara                                   Sneakers For Men
# 4                ADIDAS                     STREET ICON M Sneakers For Men
# ..                  ...                                                ...
# 95                  SFR                                   Sneakers For Men
# 96          Asian Shoes  Future-04 casual shoes for men | Latest Stylis...
# 97                 PUMA                         Ziller V2 Sneakers For Men
# 98               Layasa  Casual Sneakers White Shoes For Girls And Snea...
# 99                Sparx                            SM-162 Sneakers For Men
#
#    Price of Sneakers
# 0               ₹199
# 1               ₹282
# ...

# %% [markdown]
# ## Q7

# %%
# Opening webpage 'https://www.amazon.in/'
driver.get('https://www.amazon.in/')

# %%
# enter 'Laptop' in search input box

amazon = driver.find_element(By.ID,'twotabsearchtextbox')
amazon.send_keys('Laptop')

# %%
# clicking search Icon
ama_search = driver.find_element(By.ID,'nav-search-submit-button')
ama_search.click()

# %%
# filter CPU type as 'Intel Core i7'
cpu_type = driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[6]/li[9]/span/a/div/label/i')
cpu_type.click()

# %%
# Creating empty list for required data scraping
Lap_title = []
Lap_ratings = []
Lap_price = []

# %%
# Scrap 10 laptop Titles
lap_title = driver.find_elements(By.XPATH,'//span[@class="a-size-medium a-color-base a-text-normal"]')
for i in lap_title[:10]:
    Lap_title.append(i.text)

# %%
# Scrap 10 Laptop Ratings
Rating = []
lap_ratings = driver.find_elements(By.XPATH,'//div[@class="a-row a-size-small"]/span')
for i in lap_ratings:
    if len(i.get_attribute("aria-label").split(' ')) == 5:
        Rating.append(i.get_attribute("aria-label"))

for i in range(0,len(Rating))[0:10]:  
        Lap_ratings.append(Rating[i][0:3])

# %%
# Scrap 10 Laptop Price
lap_price = driver.find_elements(By.XPATH,'//span[@class="a-icon-alt"]')
for i in lap_price[:10]:
    Lap_price.append(i.text)

# %%
print(len(Lap_title),len(Lap_ratings),len(Lap_price))
# Out:
# 10 10 10

# %%
# creating Data Frame
Laptop_data = pd.DataFrame({'Title':Lap_title,'Ratings':Lap_ratings,'Price':Lap_price})
Laptop_data
# Out:
#                                                Title Ratings Price
# 0  ASUS VivoBook 15 (2021), 15.6-inch (39.62 cm) ...     4.0
# 1  Lenovo IdeaPad Slim 3 Intel Celeron N4020 4th ...     3.8
# 2  Lenovo V15 Intel Celeron N4020 15.6" (39.62 cm...     3.5
# 3  Lenovo IdeaPad D330 Intel Celeron N4020 10.1" ...     4.5
# 4  AVITA SATUS S111 NU14A1INC43PN-SG 14.1 FHD (35...     4.4
# 5  Lenovo IdeaPad Slim 3 Chromebook Intel Celeron...     4.5
# 6  Lenovo IdeaPad Slim 3 Chromebook Intel Celeron...     4.1
# 7  HP 14s, Intel Celeron N4500, 8GB RAM/256GB SSD...     4.0
# 8  Lenovo IdeaPad Slim 1 Intel Celeron N4020 4th ...     4.2
# 9  HP Chromebook 14a,Intel Celeron N4500 14inch(3...     4.3

# %% [markdown]
# ## Q8

# %%
# opening webpage with url 'https://www.azquotes.com/'
driver.get('https://www.azquotes.com/')

# %%
# clicking Top Quotes
clickTop = driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[1]/div/div[3]/ul/li[5]/a')
clickTop.click()

# %%
# creating List
quotes = []
authors = []
typeOfQuotes = []

# %%
# scrap quates, authores and type of quote
for page in range(0,10):
    quote_all = driver.find_elements(By.XPATH,'//a[@class="title"]') #scrap Quotes
    for i in quote_all:
        quotes.append(i.text)
    
    authors_all = driver.find_elements(By.XPATH,'//div[@class="author"]') # Scrap Authors
    for i in authors_all:
        authors.append(i.text)
    
    typeQuote = driver.find_elements(By.XPATH,'//div[@class="tags"]') # Scrap type of quotes
    for i in typeQuote:
        typeOfQuotes.append(i.text)
    next_button = driver.find_element(By.CLASS_NAME,'next')
    try:
        next_button.click()
    except:
        pass
    time.sleep(3)

# %%
# Creating Data Frame
All_Quotes = pd.DataFrame({'Quote':quotes,'Author':authors,'Type of Quote':typeOfQuotes})
All_Quotes
# Out:
#                                                  Quote              Author  \
# 0    The essence of strategy is choosing what not t...      Michael Porter
# 1    One cannot and must not try to erase the past ...          Golda Meir
# 2    Patriotism means to stand by the country. It d...  Theodore Roosevelt
# 3    Death is something inevitable. When a man has ...      Nelson Mandela
# 4    You have to love a nation that celebrates its ...        Erma Bombeck
# ..                                                 ...                 ...
# 995  Regret for the things we did can be tempered b...    Sydney J. Harris
# 996  America... just a nation of two hundred millio...  Hunter S. Thompson
# 997  For every disciplined effort there is a multip...            Jim Rohn
# 998  The spiritual journey is individual, highly pe...            Ram Dass
# 999  The mind is not a vessel to be filled but a fi...            Plutarch
#
#                                 Type of Quote
# ...

# %% [markdown]
# ## Q9

# %%
# open webpage with url 'https://www.jagranjosh.com/'
driver.get('https://www.jagranjosh.com/')

# %%
# clicking GK option
GKoption = driver.find_element(By.XPATH,'/html/body/div/div[1]/div/div[1]/div/div[6]/div/div[1]/header/div[3]/ul/li[9]/a')
GKoption.click()

# %%
# Clicking on List of all prime minister of India
all_pm = driver.find_element(By.XPATH,'/html/body/div/div/div/div[2]/div/div[10]/div/div/ul/li[2]/a')
all_pm.click()

# %%
# Create list of all required data
pm_name = []
pm_borndead = []
pm_office = []
pm_remarks = []

# %%
# scrap PM name
pm_names = driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[2]') # Prime Minister Manes
for i in pm_names:
    pm_name.append(i.text)
pm_bd = driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[3]') # scraping Borth and death 
for i in pm_bd:
    pm_borndead.append(i.text)
pm_office_li = driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[4]') # Scraping term of office
for i in pm_office_li:
    pm_office.append(i.text.replace('\n',' '))
pm_rem = driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[5]') # scraping Remarks
for i in pm_rem:
    pm_remarks.append(i.text)

# %%
print(len(pm_name),len(pm_borndead),len(pm_office),len(pm_remarks))
# Out:
# 20 18 18 18

# %%
Prime_Minister_of_India = pd.DataFrame({'Name':pm_name[:18],'Born-Dead':pm_borndead,'Term of Office':pm_office,'Remarks':pm_remarks})
Prime_Minister_of_India
# Out:
#                            Name     Born-Dead  \
# 0             Jawahar Lal Nehru   (1889–1964)
# 1     Gulzarilal Nanda (Acting)   (1898-1998)
# 2           Lal Bahadur Shastri   (1904–1966)
# 3   Gulzari Lal Nanda  (Acting)   (1898-1998)
# 4                 Indira Gandhi   (1917–1984)
# 5                 Morarji Desai   (1896–1995)
# 6                  Charan Singh   (1902–1987)
# 7                 Indira Gandhi   (1917–1984)
# 8                  Rajiv Gandhi   (1944–1991)
# 9                   V. P. Singh   (1931–2008)
# 10              Chandra Shekhar   (1927–2007)
# 11          P. V. Narasimha Rao   (1921–2004)
# 12         Atal Bihari Vajpayee  (1924- 2018)
# 13             H. D. Deve Gowda   (born 1933)
# 14           Inder Kumar Gujral   (1919–2012)
# 15         Atal Bihari Vajpayee   (1924-2018)
# 16               Manmohan Singh   (born 1932)
# 17                Narendra Modi   (born 1950)
#
#                                        Term of Office  \
# ...

# %% [markdown]
# ## Q10

# %%
# open webpage using url 'https://www.motor1.com/'
driver.get('https://www.motor1.com/')

# %%
# click on three line (Open drop down menu) 
clickThreeLine = driver.find_element(By.XPATH,'//div[@data-id="mainMenuToggle"]')
clickThreeLine.click()

# %%
#Close Subscription Popup
try:
    subcrPop = driver.find_element(By.XPATH,'//button[@class="needsclick klaviyo-close-form kl-private-reset-css-Xuajs1"]')
    subcrPop.click()
except:
    pass

# %%
# Click Drop Down Menu "Features"

feature = driver.find_element(By.XPATH,'//div[@class="m1-left-side-box"]/ul/li[5]/button')
feature.click()

# %%
# Click More Button in list option
morebutton = driver.find_element(By.XPATH,'//div[@class="m1-left-side-box"]/ul/li[6]/ul/li/a')
morebutton.click()

# %%
# Click article '50 most expensive cars in the world'
clickArticle = driver.find_element(By.XPATH,'/html/body/div[3]/div[9]/div[1]/div[1]/div/div/div[9]/div/div[1]/h3/a')
clickArticle.click()

# %%
# make empty list of requred data
CarName = []
CarPrice = []

# %%
# Scraping car name
carnames = driver.find_elements(By.XPATH,'//h3[@class="subheader"]')

for i in carnames:
    CarName.append(i.text)

# %%
# Scrping Car Price
carprice = driver.find_elements(By.XPATH,'//*[@id="article_box"]/div[1]/div[2]/div[1]/p/strong')

for i in carprice:
    if len(i.text.split(' ')) <= 4 and len(i.text.split(' ')) > 1:
        try:
            CarPrice.append(i.text.split(':')[1])
        except:
            CarPrice.append(i.text)

# %%
print(len(CarName),len(CarPrice))
# Out:
# 51 50

# %%
# Creating Data Frame

Most_Expensive_50_cars = pd.DataFrame({'Car Name':CarName[:50],'Car Price':CarPrice[:50]})
Most_Expensive_50_cars
# Out:
#                            Car Name              Car Price
# 0                         Drako GTE           $1.2 Million
# 1                     De Tomaso P72           $1.3 Million
# 2                 Ferrari LaFerrari           $1.4 Million
# 3                     Pagani Huayra           $1.4 Million
# 4                      McLaren Elva           $1.7 Million
# 5                       Czinger 21C           $1.7 Million
# 6                     Ferrari Monza           $1.7 Million
# 7                Gordon Murray T.33           $1.7 Million
# 8                 Koenigsegg Gemera           $1.7 Million
# 9                       Zenvo TSR-S           $1.7 Million
# 10               Hennessey Venom F5           $1.8 Million
# 11                  Bentley Bacalar           $1.9 Million
# 12    Hispano Suiza Carmen Boulogne           $1.9 Million
# 13           Bentley Mulliner Batur           $2.0 Million
# 14                     Deus Vayanne           $2.0 Million
# ...
